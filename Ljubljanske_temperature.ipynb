# %%
import pandas as pd 
csv_file_path = "Temp_LJ.csv"
df = pd.read_csv(csv_file_path)
df
# Out:
#      LETO  MESEC  TEMPERATURA
# 0    1986      1          0.1
# 1    1986      2         -2.8
# 2    1986      3          3.2
# 3    1986      4         10.2
# 4    1986      5         17.6
# ..    ...    ...          ...
# 415  2020      8         22.2
# 416  2020      9         17.5
# 417  2020     10         11.9
# 418  2020     11          5.3
# 419  2020     12          2.9
#
# [420 rows x 3 columns]

# %%
filt_januar = (df["MESEC"] == 1)
januar_df = df[filt_januar]
januar_df
# Out:
#      LETO  MESEC  TEMPERATURA
# 0    1986      1          0.1
# 12   1987      1         -3.4
# 24   1988      1          3.8
# 36   1989      1         -0.7
# 48   1990      1         -0.5
# 60   1991      1          0.7
# 72   1992      1          0.6
# 84   1993      1          0.9
# 96   1994      1          3.5
# 108  1995      1          1.0
# 120  1996      1         -0.8
# 132  1997      1         -0.5
# 144  1998      1          3.2
# 156  1999      1          0.6
# 168  2000      1         -1.6
# 180  2001      1          3.4
# 192  2002      1         -0.6
# 204  2003      1         -1.1
# 216  2004      1         -0.3
# 228  2005      1          0.1
# 240  2006      1         -1.6
# 252  2007      1          4.9
# 264  2008      1          2.5
# 276  2009      1         -1.5
# 288  2010      1         -1.5
# 300  2011      1          1.5
# 312  2012      1          1.6
# 324  2013      1          2.0
# 336  2014      1          5.4
# 348  2015      1          2.8
# ...

# %%
januar_df.iloc[:int(len(januar_df)/2)]["TEMPERATURA"].mean()
# Out:
# 0.5705882352941177

# %%
januar_df.iloc[int(len(januar_df)/2):]["TEMPERATURA"].mean()
# Out:
# 1.1166666666666665

# %%
import matplotlib.pyplot as plt 
plt.plot(januar_df["TEMPERATURA"],'o')

# %%
julij_filt = (df["MESEC"] == 7)
julij_df = df[julij_filt]
julij_df
# Out:
#      LETO  MESEC  TEMPERATURA
# 6    1986      7         19.6
# 18   1987      7         21.4
# 30   1988      7         22.0
# 42   1989      7         20.2
# 54   1990      7         20.2
# 66   1991      7         21.8
# 78   1992      7         21.2
# 90   1993      7         20.4
# 102  1994      7         22.5
# 114  1995      7         22.8
# 126  1996      7         19.1
# 138  1997      7         20.1
# 150  1998      7         21.5
# 162  1999      7         20.9
# 174  2000      7         19.9
# 186  2001      7         21.9
# 198  2002      7         21.3
# 210  2003      7         22.6
# 222  2004      7         20.9
# 234  2005      7         21.1
# 246  2006      7         23.6
# 258  2007      7         22.0
# 270  2008      7         21.4
# 282  2009      7         21.7
# 294  2010      7         22.9
# 306  2011      7         21.1
# 318  2012      7         22.7
# 330  2013      7         23.5
# 342  2014      7         20.8
# 354  2015      7         24.3
# ...

# %%
julij_df.iloc[:int(len(julij_df)/2)]["TEMPERATURA"].mean()
# Out:
# 20.988235294117647

# %%
julij_df.iloc[int(len(julij_df)/2):]["TEMPERATURA"].mean()
# Out:
# 22.333333333333332

# %%
plt.plot(julij_df["TEMPERATURA"],'o')

# %%
januar_df.reset_index(drop=True, inplace=True)

# %%
januar_df
# Out:
#     LETO  MESEC  TEMPERATURA
# 0   1986      1          0.1
# 1   1987      1         -3.4
# 2   1988      1          3.8
# 3   1989      1         -0.7
# 4   1990      1         -0.5
# 5   1991      1          0.7
# 6   1992      1          0.6
# 7   1993      1          0.9
# 8   1994      1          3.5
# 9   1995      1          1.0
# 10  1996      1         -0.8
# 11  1997      1         -0.5
# 12  1998      1          3.2
# 13  1999      1          0.6
# 14  2000      1         -1.6
# 15  2001      1          3.4
# 16  2002      1         -0.6
# 17  2003      1         -1.1
# 18  2004      1         -0.3
# 19  2005      1          0.1
# 20  2006      1         -1.6
# 21  2007      1          4.9
# 22  2008      1          2.5
# 23  2009      1         -1.5
# 24  2010      1         -1.5
# 25  2011      1          1.5
# 26  2012      1          1.6
# 27  2013      1          2.0
# 28  2014      1          5.4
# 29  2015      1          2.8
# 30  2016      1          1.1
# ...

# %%
julij_df.reset_index(drop=True, inplace=True)
julij_df
# Out:
#     LETO  MESEC  TEMPERATURA
# 0   1986      7         19.6
# 1   1987      7         21.4
# 2   1988      7         22.0
# 3   1989      7         20.2
# 4   1990      7         20.2
# 5   1991      7         21.8
# 6   1992      7         21.2
# 7   1993      7         20.4
# 8   1994      7         22.5
# 9   1995      7         22.8
# 10  1996      7         19.1
# 11  1997      7         20.1
# 12  1998      7         21.5
# 13  1999      7         20.9
# 14  2000      7         19.9
# 15  2001      7         21.9
# 16  2002      7         21.3
# 17  2003      7         22.6
# 18  2004      7         20.9
# 19  2005      7         21.1
# 20  2006      7         23.6
# 21  2007      7         22.0
# 22  2008      7         21.4
# 23  2009      7         21.7
# 24  2010      7         22.9
# 25  2011      7         21.1
# 26  2012      7         22.7
# 27  2013      7         23.5
# 28  2014      7         20.8
# 29  2015      7         24.3
# 30  2016      7         23.2
# ...

# %%
pod_df = pd.DataFrame({"indeks":[i for i in range(35)], "stolpec": [1 for i in range(35)]})
pod_df
# Out:
#     indeks  stolpec
# 0        0        1
# 1        1        1
# 2        2        1
# 3        3        1
# 4        4        1
# 5        5        1
# 6        6        1
# 7        7        1
# 8        8        1
# 9        9        1
# 10      10        1
# 11      11        1
# 12      12        1
# 13      13        1
# 14      14        1
# 15      15        1
# 16      16        1
# 17      17        1
# 18      18        1
# 19      19        1
# 20      20        1
# 21      21        1
# 22      22        1
# 23      23        1
# 24      24        1
# 25      25        1
# 26      26        1
# 27      27        1
# 28      28        1
# 29      29        1
# 30      30        1
# 31      31        1
# 32      32        1
# 33      33        1
# 34      34        1

# %%
ATA = (pod_df.T).dot(pod_df)

# %%
VR = (pod_df.T).dot(januar_df["TEMPERATURA"])

# %%
VR
# Out:
# indeks     676.0
# stolpec     29.8
# dtype: float64

# %%
import numpy
A_array = ATA.to_numpy()
b_array = VR.to_numpy()

# Rešimo linearni sistem Ax = b
x_array = numpy.linalg.solve(A_array, b_array)

x_array
# Out:
# array([0.04745098, 0.0447619 ])

# %%
x_values = [i for i in range(35)]
y_values = [(x_array[0]*i+x_array[1]) for i in range(35)]
plt.plot(x_values,y_values,c='r')
plt.scatter(x_values, januar_df["TEMPERATURA"])

plt.show()

# %% [markdown]
# Ponovimo enako še za julijske temperature. Najprej sestavimo matriko ATA1 in VR1. Opazimo, da je ATA = ATA1.

# %%
VR1 = (pod_df.T).dot(julij_df["TEMPERATURA"])

# %%
b_array1 = VR1.to_numpy()

# Rešimo linearni sistem Ax = b
x_array1 = numpy.linalg.solve(A_array, b_array1)

x_array1
# Out:
# array([ 0.06747899, 20.53285714])

# %%
y_values1 = [(x_array1[0]*i+x_array1[1]) for i in range(35)]
plt.plot(x_values,y_values1,c='r')
plt.scatter(x_values, julij_df["TEMPERATURA"])

plt.show()
